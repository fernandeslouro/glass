# %%
import torch

# %%
model = generator()
checkpoint = torch.load(‘path/001_G.pth’, map_location = str(device))
model.load_state_dict(checkpoint, strict=False)
model.to(device)
model.float()
model.eval()
# Out:
#   File "<ipython-input-2-fec86a4dec37>", line 2
#     checkpoint = torch.load(‘path/001_G.pth’, map_location = str(device))
#                                 ^
# SyntaxError: invalid character in identifier
